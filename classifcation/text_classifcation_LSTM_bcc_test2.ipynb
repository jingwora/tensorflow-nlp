# %% [markdown]
# # LSTM Intent Classification
# ---
# **Dataset:** bbc news (2225 samples) News contents with 5 categories (Sport, Business, Politics, Tech and Others)
#
# **Model:**   multiclass classification model : LSTM
#
# **Training:**  Colab (GPU)
#
# **Process:**  1. Dataset Load  ➔ 2. Data processing ➔ 3. Model Training  ➔ 4. Model Evaluation ➔ 5. Prediction
#
# **Result:**  Accuracy = 0.63, run time = 9 minutes

# %% [markdown]
# ## ライブラリ

# %%
#　ライブラリ

import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
import nltk
import re
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Bidirectional, Embedding, Dropout
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1. データ読み込

# %%
# google driveと接続

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# intent, unique_intent, sentencesに分ける

def load_dataset(filename):
  df = pd.read_csv(filename, encoding = "latin1", header=0)
  print(df.head())
  category = df["category"]
  unique_category = list(set(category))
  text = list(df["text"])
  
  return (df, category, unique_category, text)

# %%
# データ読み込

dataset = "/content/drive/My Drive/dataset/bbc/bbc-text.csv"
df, category, unique_category, text = load_dataset(dataset)
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
import matplotlib.pyplot as plt

df.groupby('category').text.count().plot.bar(ylim=0)
plt.show()

# %%
# サンプルデータを確認

print(text[:5])
# Out:
# ['tv future in the hands of viewers with home theatre systems  plasma high-definition tvs  and digital video recorders moving into the living room  the way people watch tv will be radically different in five years  time.  that is according to an expert panel which gathered at the annual consumer electronics show in las vegas to discuss how these new technologies will impact one of our favourite pastimes. with the us leading the trend  programmes and other content will be delivered to viewers via home networks  through cable  satellite  telecoms companies  and broadband service providers to front rooms and portable devices.  one of the most talked-about technologies of ces has been digital and personal video recorders (dvr and pvr). these set-top boxes  like the us s tivo and the uk s sky+ system  allow people to record  store  play  pause and forward wind tv programmes when they want.  essentially  the technology allows for much more personalised tv. they are also being built-in to high-definition tv sets  which are big business in japan and the us  but slower to take off in europe because of the lack of high-definition programming. not only can people forward wind through adverts  they can also forget about abiding by network and channel schedules  putting together their own a-la-carte entertainment. but some us networks and cable and satellite companies are worried about what it means for them in terms of advertising revenues as well as  brand identity  and viewer loyalty to channels. although the us leads in this technology at the moment  it is also a concern that is being raised in europe  particularly with the growing uptake of services like sky+.  what happens here today  we will see in nine months to a years  time in the uk   adam hume  the bbc broadcast s futurologist told the bbc news website. for the likes of the bbc  there are no issues of lost advertising revenue yet. it is a more pressing issue at the moment for commercial uk broadcasters  but brand loyalty is important for everyone.  we will be talking more about content brands rather than network brands   said tim hanlon  from brand communications firm starcom mediavest.  the reality is that with broadband connections  anybody can be the producer of content.  he added:  the challenge now is that it is hard to promote a programme with so much choice.   what this means  said stacey jolna  senior vice president of tv guide tv group  is that the way people find the content they want to watch has to be simplified for tv viewers. it means that networks  in us terms  or channels could take a leaf out of google s book and be the search engine of the future  instead of the scheduler to help people find what they want to watch. this kind of channel model might work for the younger ipod generation which is used to taking control of their gadgets and what they play on them. but it might not suit everyone  the panel recognised. older generations are more comfortable with familiar schedules and channel brands because they know what they are getting. they perhaps do not want so much of the choice put into their hands  mr hanlon suggested.  on the other end  you have the kids just out of diapers who are pushing buttons already - everything is possible and available to them   said mr hanlon.  ultimately  the consumer will tell the market they want.   of the 50 000 new gadgets and technologies being showcased at ces  many of them are about enhancing the tv-watching experience. high-definition tv sets are everywhere and many new models of lcd (liquid crystal display) tvs have been launched with dvr capability built into them  instead of being external boxes. one such example launched at the show is humax s 26-inch lcd tv with an 80-hour tivo dvr and dvd recorder. one of the us s biggest satellite tv companies  directtv  has even launched its own branded dvr at the show with 100-hours of recording capability  instant replay  and a search function. the set can pause and rewind tv fo ...

# %% [markdown]
# ## 2. データ準備

# %%
# nltkのstopwordsとtokenizersを読み込む

nltk.download("stopwords")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#define stemmer
stemmer = LancasterStemmer()

# %%
# データクリーニング

def cleaning(text):
  words = []
  for s in text:
    clean = re.sub(r'[^ a-z A-Z 0-9]', " ", s)
    w = word_tokenize(clean)
    #stemming
    words.append([i.lower() for i in w])
    
  return words

cleaned_words = cleaning(text)
print(len(cleaned_words))
print(cleaned_words[:2])
# Out:
# 2225
# [['tv', 'future', 'in', 'the', 'hands', 'of', 'viewers', 'with', 'home', 'theatre', 'systems', 'plasma', 'high', 'definition', 'tvs', 'and', 'digital', 'video', 'recorders', 'moving', 'into', 'the', 'living', 'room', 'the', 'way', 'people', 'watch', 'tv', 'will', 'be', 'radically', 'different', 'in', 'five', 'years', 'time', 'that', 'is', 'according', 'to', 'an', 'expert', 'panel', 'which', 'gathered', 'at', 'the', 'annual', 'consumer', 'electronics', 'show', 'in', 'las', 'vegas', 'to', 'discuss', 'how', 'these', 'new', 'technologies', 'will', 'impact', 'one', 'of', 'our', 'favourite', 'pastimes', 'with', 'the', 'us', 'leading', 'the', 'trend', 'programmes', 'and', 'other', 'content', 'will', 'be', 'delivered', 'to', 'viewers', 'via', 'home', 'networks', 'through', 'cable', 'satellite', 'telecoms', 'companies', 'and', 'broadband', 'service', 'providers', 'to', 'front', 'rooms', 'and', 'portable', 'devices', 'one', 'of', 'the', 'most', 'talked', 'about', 'technologies', 'of', 'ces', 'has', 'been', 'digital', 'and', 'personal', 'video', 'recorders', 'dvr', 'and', 'pvr', 'these', 'set', 'top', 'boxes', 'like', 'the', 'us', 's', 'tivo', 'and', 'the', 'uk', 's', 'sky', 'system', 'allow', 'people', 'to', 'record', 'store', 'play', 'pause', 'and', 'forward', 'wind', 'tv', 'programmes', 'when', 'they', 'want', 'essentially', 'the', 'technology', 'allows', 'for', 'much', 'more', 'personalised', 'tv', 'they', 'are', 'also', 'being', 'built', 'in', 'to', 'high', 'definition', 'tv', 'sets', 'which', 'are', 'big', 'business', 'in', 'japan', 'and', 'the', 'us', 'but', 'slower', 'to', 'take', 'off', 'in', 'europe', 'because', 'of', 'the', 'lack', 'of', 'high', 'definition', 'programming', 'not', 'only', 'can', 'people', 'forward', 'wind', 'through', 'adverts', 'they', 'can', 'also', 'forget', 'about', 'abiding', 'by', 'network', 'and', 'channel', 'schedules', 'putting', 'together', 'their', 'own', 'a', 'la', 'carte', 'entertainment', 'but', 'some', 'us', 'networks', 'and', 'cable', 'and', 'satellite', 'companies', 'are', 'worried', 'about', 'what', 'it', 'means', 'for', 'them', 'in', 'terms', 'of', 'advertising', 'revenues', 'as', 'well', 'as', 'brand', 'identity', 'and', 'viewer', 'loyalty', 'to', 'channels', 'although', 'the', 'us', 'leads', 'in', 'this', 'technology', 'at', 'the', 'moment', 'it', 'is', 'also', 'a', 'concern', 'that', 'is', 'being', 'raised', 'in', 'europe', 'particularly', 'with', 'the', 'growing', 'uptake', 'of', 'services', 'like', 'sky', 'what', 'happens', 'here', 'today', 'we', 'will', 'see', 'in', 'nine', 'months', 'to', 'a', 'years', 'time', 'in', 'the', 'uk', 'adam', 'hume', 'the', 'bbc', 'broadcast', 's', 'futurologist', 'told', 'the', 'bbc', 'news', 'website', 'for', 'the', 'likes', 'of', 'the', 'bbc', 'there', 'are', 'no', 'issues', 'of', 'lost', 'advertising', 'revenue', 'yet', 'it', 'is', 'a', 'more', 'pressing', 'issue', 'at', 'the', 'moment', 'for', 'commercial', 'uk', 'broadcasters', 'but', 'brand', 'loyalty', 'is', 'important', 'for', 'everyone', 'we', 'will', 'be', 'talking', 'more', 'about', 'content', 'brands', 'rather', 'than', 'network', 'brands', 'said', 'tim', 'hanlon', 'from', 'brand', 'communications', 'firm', 'starcom', 'mediavest', 'the', 'reality', 'is', 'that', 'with', 'broadband', 'connections', 'anybody', 'can', 'be', 'the', 'producer', 'of', 'content', 'he', 'added', 'the', 'challenge', 'now', 'is', 'that', 'it', 'is', 'hard', 'to', 'promote', 'a', 'programme', 'with', 'so', 'much', 'choice', 'what', 'this', 'means', 'said', 'stacey', 'jolna', 'senior', 'vice', 'president', 'of', 'tv', 'guide', 'tv', 'group', 'is', 'that', 'the', 'way', 'people', 'find', 'the', 'content', 'they', 'want', 'to', 'watch', 'has', 'to', 'be', 'simplified', 'for', 'tv', 'viewers', 'it', 'means', 'that', 'networks', 'in', 'us', 'terms', 'or', 'channels', 'could', 'take', 'a', 'leaf', 'out', 'of', 'google', 's', 'book', 'and', 'be', 'the', 'search', 'engine', 'of', 'the', 'future', 'instead', 'of', 'the', 'schedule ...

# %%
# Tokenizerを作成

def create_tokenizer(words, filters = '!"#$%&()*+,-./:;<=>?@[\]^_`{|}~'):
  token = Tokenizer(filters = filters)
  token.fit_on_texts(words)
  return token

# max_lengthの設定
def max_length(words):
  return(len(max(words, key = len)))


word_tokenizer = create_tokenizer(cleaned_words)
vocab_size = len(word_tokenizer.word_index) + 1
# max_length = max_length(cleaned_words)
max_length = 250

print("Vocab Size = %d and Maximum length = %d" % (vocab_size, max_length))
# Out:
# Vocab Size = 29457 and Maximum length = 250

# %%
def encoding_doc(token, words):
  return(token.texts_to_sequences(words))

encoded_doc = encoding_doc(word_tokenizer, cleaned_words)

def padding_doc(encoded_doc, max_length):
  return(pad_sequences(encoded_doc, maxlen = max_length, padding = "post"))

padded_doc = padding_doc(encoded_doc, max_length)

# %%
padded_doc[:5]
# Out:
# array([[   11,   465,    27, ...,    66,    29,   166],
#        [ 1709,     7,   481, ...,  2480,    30,  7014],
#        [ 5058,  7015,     3, ...,  1968,     0,     0],
#        [ 5276,     2,     5, ...,   421,   474,   325],
#        [ 5277,  3133,    19, ...,  2305, 14956, 12596]], dtype=int32)

# %%
print("Shape of padded docs = ",padded_doc.shape)
# Out:
# Shape of padded docs =  (2225, 250)

# %%
# tokenizer with filter changed
output_tokenizer = create_tokenizer(unique_category, filters = '!"#$%&()*+,-/:;<=>?@[\]^`{|}~')

# %%
output_tokenizer.word_index
# Out:
# {'business': 3, 'entertainment': 2, 'politics': 1, 'sport': 5, 'tech': 4}

# %%
# Tokenizer

encoded_output = encoding_doc(output_tokenizer, category)

encoded_output = np.array(encoded_output).reshape(len(encoded_output), 1)

encoded_output.shape
# Out:
# (2225, 1)

# %%
# one hot encoder

def one_hot(encode):
  o = OneHotEncoder(sparse = False)
  return(o.fit_transform(encode))

output_one_hot = one_hot(encoded_output)

output_one_hot.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# (2225, 5)

# %%
# 学習とテストを分ける

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(padded_doc, output_one_hot, shuffle = True,  stratify = category, test_size = 0.2, random_state=11)

print("Shape of X_train = %s and y_train = %s" % (X_train.shape, y_train.shape))
print("Shape of X_test = %s and y_test = %s" % (X_test.shape, y_test.shape))
# Out:
# Shape of X_train = (1780, 250) and y_train = (1780, 5)
# Shape of X_test = (445, 250) and y_test = (445, 5)

# %% [markdown]
# ## 3. 学習

# %%
# モデルの設定

def create_model(vocab_size, max_length):
  model = Sequential()
  model.add(Embedding(vocab_size, 128, input_length = max_length, trainable = False))
  model.add(Bidirectional(LSTM(128)))
#   model.add(LSTM(128))
  model.add(Dense(32, activation = "relu"))
  model.add(Dropout(0.65))
  model.add(Dense(5, activation = "softmax"))
  
  return model

model = create_model(vocab_size, max_length)

model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0725 06:19:51.217615 139978917910400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0725 06:19:51.236032 139978917910400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0725 06:19:51.238065 139978917910400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0725 06:19:51.818633 139978917910400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0725 06:19:51.827732 139978917910400 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0725 06:19:51.828758 139978917910400 nn_ops.py:4224] Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# W0725 06:19:51.855573 139978917910400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0725 06:19:51.877225 139978917910400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 250, 128)          3770496
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               263168
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 4,042,053
# Trainable params: 271,557
# Non-trainable params: 3,770,496
# _________________________________________________________________

# %%
# モデル学習
from datetime import datetime

start_time = datetime.now()

filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

hist = model.fit(X_train, y_train, epochs = 150, batch_size = 200, validation_data = (X_test, y_test), callbacks = [checkpoint])

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Train on 1780 samples, validate on 445 samples
# Epoch 1/150
# 1780/1780 [==============================] - 9s 5ms/step - loss: 0.7080 - acc: 0.7337 - val_loss: 1.1229 - val_acc: 0.6382
#
# Epoch 00001: val_acc improved from -inf to 0.63820, saving model to model.h5
# Epoch 2/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6638 - acc: 0.7483 - val_loss: 1.0032 - val_acc: 0.6562
#
# Epoch 00002: val_acc improved from 0.63820 to 0.65618, saving model to model.h5
# Epoch 3/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6349 - acc: 0.7635 - val_loss: 1.0547 - val_acc: 0.6562
#
# Epoch 00003: val_acc improved from 0.65618 to 0.65618, saving model to model.h5
# Epoch 4/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6291 - acc: 0.7556 - val_loss: 1.0889 - val_acc: 0.6045
#
# Epoch 00004: val_acc did not improve from 0.65618
# Epoch 5/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6885 - acc: 0.7393 - val_loss: 1.0359 - val_acc: 0.6674
#
# Epoch 00005: val_acc improved from 0.65618 to 0.66742, saving model to model.h5
# Epoch 6/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6501 - acc: 0.7573 - val_loss: 1.0076 - val_acc: 0.6674
#
# Epoch 00006: val_acc did not improve from 0.66742
# Epoch 7/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6394 - acc: 0.7612 - val_loss: 1.0588 - val_acc: 0.6247
#
# Epoch 00007: val_acc did not improve from 0.66742
# Epoch 8/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6178 - acc: 0.7657 - val_loss: 1.0494 - val_acc: 0.6472
#
# Epoch 00008: val_acc did not improve from 0.66742
# Epoch 9/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6203 - acc: 0.7747 - val_loss: 1.0462 - val_acc: 0.6427
#
# Epoch 00009: val_acc did not improve from 0.66742
# Epoch 10/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6342 - acc: 0.7680 - val_loss: 1.0793 - val_acc: 0.6674
#
# Epoch 00010: val_acc improved from 0.66742 to 0.66742, saving model to model.h5
# Epoch 11/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6350 - acc: 0.7697 - val_loss: 1.1196 - val_acc: 0.6202
#
# Epoch 00011: val_acc did not improve from 0.66742
# Epoch 12/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6570 - acc: 0.7551 - val_loss: 1.0742 - val_acc: 0.6494
#
# Epoch 00012: val_acc did not improve from 0.66742
# Epoch 13/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6372 - acc: 0.7567 - val_loss: 1.0879 - val_acc: 0.6292
#
# Epoch 00013: val_acc did not improve from 0.66742
# Epoch 14/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6534 - acc: 0.7624 - val_loss: 1.0634 - val_acc: 0.6517
#
# Epoch 00014: val_acc did not improve from 0.66742
# Epoch 15/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6237 - acc: 0.7545 - val_loss: 1.1091 - val_acc: 0.6292
#
# Epoch 00015: val_acc did not improve from 0.66742
# Epoch 16/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6042 - acc: 0.7697 - val_loss: 1.0618 - val_acc: 0.6427
#
# Epoch 00016: val_acc did not improve from 0.66742
# Epoch 17/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6006 - acc: 0.7663 - val_loss: 1.2038 - val_acc: 0.6135
#
# Epoch 00017: val_acc did not improve from 0.66742
# Epoch 18/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6725 - acc: 0.7500 - val_loss: 1.2176 - val_acc: 0.5843
#
# Epoch 00018: val_acc did not improve from 0.66742
# Epoch 19/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.7225 - acc: 0.7135 - val_loss: 1.1854 - val_acc: 0.5843
#
# Epoch 00019: val_acc did not improve from 0.66742
# Epoch 20/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.7242 - acc: 0.7292 - val_loss: 1.1582 - val_acc: 0.5978
#
# Epoch 00020: val_acc did not improve from 0.66742
# Epoch 21/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6715 - acc: 0.7416 - val_loss: 1.1200 - val_acc: 0.6135
#
# Epoch 00021: val_acc did not improve from 0.66742
# Epoch 22/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6525 - acc: 0.7680 - val_loss: 1.1562 - val_acc: 0.6045
#
# Epoch 00022: val_acc did not improve from 0.66742
# Epoch 23/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6275 - acc: 0.7753 - val_loss: 1.0637 - val_acc: 0.6472
#
# Epoch 00023: val_acc did not improve from 0.66742
# Epoch 24/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6161 - acc: 0.7831 - val_loss: 1.2201 - val_acc: 0.6135
#
# Epoch 00024: val_acc did not improve from 0.66742
# Epoch 25/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6059 - acc: 0.7680 - val_loss: 1.1588 - val_acc: 0.6180
#
# Epoch 00025: val_acc did not improve from 0.66742
# Epoch 26/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6481 - acc: 0.7663 - val_loss: 1.1874 - val_acc: 0.6202
#
# Epoch 00026: val_acc did not improve from 0.66742
# Epoch 27/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6459 - acc: 0.7455 - val_loss: 1.2709 - val_acc: 0.6135
#
# Epoch 00027: val_acc did not improve from 0.66742
# Epoch 28/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.6121 - acc: 0.7590 - val_loss: 1.2763 - val_acc: 0.6247
#
# Epoch 00028: val_acc did not improve from 0.66742
# Epoch 29/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.5355 - acc: 0.7888 - val_loss: 1.1606 - val_acc: 0.6404
#
# Epoch 00029: val_acc did not improve from 0.66742
# Epoch 30/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.5185 - acc: 0.8022 - val_loss: 1.1493 - val_acc: 0.6584
#
# Epoch 00030: val_acc did not improve from 0.66742
# Epoch 31/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4971 - acc: 0.8073 - val_loss: 1.0659 - val_acc: 0.6809
#
# Epoch 00031: val_acc improved from 0.66742 to 0.68090, saving model to model.h5
# Epoch 32/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4917 - acc: 0.8197 - val_loss: 1.1810 - val_acc: 0.6382
#
# Epoch 00032: val_acc did not improve from 0.68090
# Epoch 33/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4745 - acc: 0.8309 - val_loss: 1.1799 - val_acc: 0.6584
#
# Epoch 00033: val_acc did not improve from 0.68090
# Epoch 34/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.5067 - acc: 0.8281 - val_loss: 1.1936 - val_acc: 0.6809
#
# Epoch 00034: val_acc improved from 0.68090 to 0.68090, saving model to model.h5
# Epoch 35/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4887 - acc: 0.8090 - val_loss: 1.2465 - val_acc: 0.6247
#
# Epoch 00035: val_acc did not improve from 0.68090
# Epoch 36/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4958 - acc: 0.8202 - val_loss: 1.1064 - val_acc: 0.6607
#
# Epoch 00036: val_acc did not improve from 0.68090
# Epoch 37/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4671 - acc: 0.8275 - val_loss: 1.1937 - val_acc: 0.6831
#
# Epoch 00037: val_acc improved from 0.68090 to 0.68315, saving model to model.h5
# Epoch 38/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4785 - acc: 0.8236 - val_loss: 1.2344 - val_acc: 0.6427
#
# Epoch 00038: val_acc did not improve from 0.68315
# Epoch 39/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4886 - acc: 0.8236 - val_loss: 1.3407 - val_acc: 0.6517
#
# Epoch 00039: val_acc did not improve from 0.68315
# Epoch 40/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4923 - acc: 0.8208 - val_loss: 1.1862 - val_acc: 0.6472
#
# Epoch 00040: val_acc did not improve from 0.68315
# Epoch 41/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4676 - acc: 0.8421 - val_loss: 1.1868 - val_acc: 0.6539
#
# Epoch 00041: val_acc did not improve from 0.68315
# Epoch 42/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4488 - acc: 0.8382 - val_loss: 1.1790 - val_acc: 0.6764
#
# Epoch 00042: val_acc did not improve from 0.68315
# Epoch 43/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4403 - acc: 0.8494 - val_loss: 1.2539 - val_acc: 0.6719
#
# Epoch 00043: val_acc did not improve from 0.68315
# Epoch 44/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4017 - acc: 0.8629 - val_loss: 1.1570 - val_acc: 0.6944
#
# Epoch 00044: val_acc improved from 0.68315 to 0.69438, saving model to model.h5
# Epoch 45/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3799 - acc: 0.8607 - val_loss: 1.1785 - val_acc: 0.6899
#
# Epoch 00045: val_acc did not improve from 0.69438
# Epoch 46/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3777 - acc: 0.8657 - val_loss: 1.2544 - val_acc: 0.6921
#
# Epoch 00046: val_acc did not improve from 0.69438
# Epoch 47/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3707 - acc: 0.8635 - val_loss: 1.3031 - val_acc: 0.6809
#
# Epoch 00047: val_acc did not improve from 0.69438
# Epoch 48/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4261 - acc: 0.8410 - val_loss: 1.5233 - val_acc: 0.5843
#
# Epoch 00048: val_acc did not improve from 0.69438
# Epoch 49/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.5807 - acc: 0.7854 - val_loss: 1.2640 - val_acc: 0.6607
#
# Epoch 00049: val_acc did not improve from 0.69438
# Epoch 50/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4230 - acc: 0.8421 - val_loss: 1.2146 - val_acc: 0.6449
#
# Epoch 00050: val_acc did not improve from 0.69438
# Epoch 51/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4901 - acc: 0.8326 - val_loss: 1.2809 - val_acc: 0.6315
#
# Epoch 00051: val_acc did not improve from 0.69438
# Epoch 52/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4501 - acc: 0.8410 - val_loss: 1.3495 - val_acc: 0.6202
#
# Epoch 00052: val_acc did not improve from 0.69438
# Epoch 53/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4588 - acc: 0.8270 - val_loss: 1.3292 - val_acc: 0.6427
#
# Epoch 00053: val_acc did not improve from 0.69438
# Epoch 54/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4352 - acc: 0.8433 - val_loss: 1.3124 - val_acc: 0.6539
#
# Epoch 00054: val_acc did not improve from 0.69438
# Epoch 55/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3996 - acc: 0.8596 - val_loss: 1.2843 - val_acc: 0.6562
#
# Epoch 00055: val_acc did not improve from 0.69438
# Epoch 56/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3341 - acc: 0.8843 - val_loss: 1.2438 - val_acc: 0.6697
#
# Epoch 00056: val_acc did not improve from 0.69438
# Epoch 57/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3332 - acc: 0.8820 - val_loss: 1.2755 - val_acc: 0.6921
#
# Epoch 00057: val_acc did not improve from 0.69438
# Epoch 58/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3079 - acc: 0.8916 - val_loss: 1.3509 - val_acc: 0.6831
#
# Epoch 00058: val_acc did not improve from 0.69438
# Epoch 59/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3238 - acc: 0.8876 - val_loss: 1.4489 - val_acc: 0.6652
#
# Epoch 00059: val_acc did not improve from 0.69438
# Epoch 60/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2893 - acc: 0.9028 - val_loss: 1.3099 - val_acc: 0.6899
#
# Epoch 00060: val_acc did not improve from 0.69438
# Epoch 61/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3417 - acc: 0.8736 - val_loss: 1.3475 - val_acc: 0.6517
#
# Epoch 00061: val_acc did not improve from 0.69438
# Epoch 62/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3845 - acc: 0.8551 - val_loss: 1.3897 - val_acc: 0.6472
#
# Epoch 00062: val_acc did not improve from 0.69438
# Epoch 63/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4668 - acc: 0.8275 - val_loss: 1.4218 - val_acc: 0.6315
#
# Epoch 00063: val_acc did not improve from 0.69438
# Epoch 64/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3478 - acc: 0.8736 - val_loss: 1.3543 - val_acc: 0.6787
#
# Epoch 00064: val_acc did not improve from 0.69438
# Epoch 65/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4311 - acc: 0.8528 - val_loss: 1.5428 - val_acc: 0.6292
#
# Epoch 00065: val_acc did not improve from 0.69438
# Epoch 66/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3261 - acc: 0.8803 - val_loss: 1.6053 - val_acc: 0.6562
#
# Epoch 00066: val_acc did not improve from 0.69438
# Epoch 67/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3207 - acc: 0.8770 - val_loss: 1.4258 - val_acc: 0.6472
#
# Epoch 00067: val_acc did not improve from 0.69438
# Epoch 68/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2796 - acc: 0.8994 - val_loss: 1.3183 - val_acc: 0.6899
#
# Epoch 00068: val_acc did not improve from 0.69438
# Epoch 69/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2657 - acc: 0.9006 - val_loss: 1.3565 - val_acc: 0.6854
#
# Epoch 00069: val_acc did not improve from 0.69438
# Epoch 70/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2693 - acc: 0.9039 - val_loss: 1.4013 - val_acc: 0.7079
#
# Epoch 00070: val_acc improved from 0.69438 to 0.70787, saving model to model.h5
# Epoch 71/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2512 - acc: 0.9084 - val_loss: 1.4681 - val_acc: 0.6764
#
# Epoch 00071: val_acc did not improve from 0.70787
# Epoch 72/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2315 - acc: 0.9157 - val_loss: 1.5418 - val_acc: 0.6787
#
# Epoch 00072: val_acc did not improve from 0.70787
# Epoch 73/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2170 - acc: 0.9169 - val_loss: 1.5616 - val_acc: 0.6809
#
# Epoch 00073: val_acc did not improve from 0.70787
# Epoch 74/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2214 - acc: 0.9247 - val_loss: 1.4679 - val_acc: 0.7011
#
# Epoch 00074: val_acc did not improve from 0.70787
# Epoch 75/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3153 - acc: 0.8803 - val_loss: 1.5598 - val_acc: 0.6921
#
# Epoch 00075: val_acc did not improve from 0.70787
# Epoch 76/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3620 - acc: 0.8747 - val_loss: 1.4584 - val_acc: 0.6607
#
# Epoch 00076: val_acc did not improve from 0.70787
# Epoch 77/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3088 - acc: 0.8966 - val_loss: 1.3932 - val_acc: 0.6854
#
# Epoch 00077: val_acc did not improve from 0.70787
# Epoch 78/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2522 - acc: 0.9124 - val_loss: 1.3909 - val_acc: 0.6989
#
# Epoch 00078: val_acc did not improve from 0.70787
# Epoch 79/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2473 - acc: 0.9112 - val_loss: 1.5050 - val_acc: 0.6876
#
# Epoch 00079: val_acc did not improve from 0.70787
# Epoch 80/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2626 - acc: 0.9174 - val_loss: 1.4749 - val_acc: 0.6989
#
# Epoch 00080: val_acc did not improve from 0.70787
# Epoch 81/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3534 - acc: 0.8719 - val_loss: 1.5061 - val_acc: 0.6270
#
# Epoch 00081: val_acc did not improve from 0.70787
# Epoch 82/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3094 - acc: 0.8871 - val_loss: 1.4751 - val_acc: 0.6787
#
# Epoch 00082: val_acc did not improve from 0.70787
# Epoch 83/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2686 - acc: 0.9146 - val_loss: 1.4440 - val_acc: 0.7213
#
# Epoch 00083: val_acc improved from 0.70787 to 0.72135, saving model to model.h5
# Epoch 84/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3201 - acc: 0.8944 - val_loss: 1.7088 - val_acc: 0.6472
#
# Epoch 00084: val_acc did not improve from 0.72135
# Epoch 85/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3186 - acc: 0.8876 - val_loss: 1.6210 - val_acc: 0.6382
#
# Epoch 00085: val_acc did not improve from 0.72135
# Epoch 86/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3409 - acc: 0.8719 - val_loss: 1.6042 - val_acc: 0.6225
#
# Epoch 00086: val_acc did not improve from 0.72135
# Epoch 87/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3020 - acc: 0.8927 - val_loss: 1.4640 - val_acc: 0.6921
#
# Epoch 00087: val_acc did not improve from 0.72135
# Epoch 88/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2479 - acc: 0.9152 - val_loss: 1.4997 - val_acc: 0.6876
#
# Epoch 00088: val_acc did not improve from 0.72135
# Epoch 89/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2132 - acc: 0.9236 - val_loss: 1.5828 - val_acc: 0.6944
#
# Epoch 00089: val_acc did not improve from 0.72135
# Epoch 90/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2107 - acc: 0.9253 - val_loss: 1.5655 - val_acc: 0.6989
#
# Epoch 00090: val_acc did not improve from 0.72135
# Epoch 91/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2116 - acc: 0.9281 - val_loss: 1.7346 - val_acc: 0.6539
#
# Epoch 00091: val_acc did not improve from 0.72135
# Epoch 92/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2878 - acc: 0.8910 - val_loss: 1.6221 - val_acc: 0.6247
#
# Epoch 00092: val_acc did not improve from 0.72135
# Epoch 93/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3446 - acc: 0.8730 - val_loss: 1.5184 - val_acc: 0.6382
#
# Epoch 00093: val_acc did not improve from 0.72135
# Epoch 94/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4502 - acc: 0.8404 - val_loss: 1.7437 - val_acc: 0.5730
#
# Epoch 00094: val_acc did not improve from 0.72135
# Epoch 95/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.4648 - acc: 0.8309 - val_loss: 1.5065 - val_acc: 0.6157
#
# Epoch 00095: val_acc did not improve from 0.72135
# Epoch 96/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3079 - acc: 0.8831 - val_loss: 1.5316 - val_acc: 0.6472
#
# Epoch 00096: val_acc did not improve from 0.72135
# Epoch 97/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2725 - acc: 0.8966 - val_loss: 1.5348 - val_acc: 0.6674
#
# Epoch 00097: val_acc did not improve from 0.72135
# Epoch 98/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2299 - acc: 0.9197 - val_loss: 1.5660 - val_acc: 0.6921
#
# Epoch 00098: val_acc did not improve from 0.72135
# Epoch 99/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1970 - acc: 0.9275 - val_loss: 1.5823 - val_acc: 0.6787
#
# Epoch 00099: val_acc did not improve from 0.72135
# Epoch 100/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2202 - acc: 0.9152 - val_loss: 1.6087 - val_acc: 0.6787
#
# Epoch 00100: val_acc did not improve from 0.72135
# Epoch 101/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1931 - acc: 0.9303 - val_loss: 1.7743 - val_acc: 0.6697
#
# Epoch 00101: val_acc did not improve from 0.72135
# Epoch 102/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1889 - acc: 0.9270 - val_loss: 1.7418 - val_acc: 0.6764
#
# Epoch 00102: val_acc did not improve from 0.72135
# Epoch 103/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2483 - acc: 0.9067 - val_loss: 1.7302 - val_acc: 0.6697
#
# Epoch 00103: val_acc did not improve from 0.72135
# Epoch 104/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2366 - acc: 0.9146 - val_loss: 1.7618 - val_acc: 0.6719
#
# Epoch 00104: val_acc did not improve from 0.72135
# Epoch 105/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1872 - acc: 0.9298 - val_loss: 1.9585 - val_acc: 0.6607
#
# Epoch 00105: val_acc did not improve from 0.72135
# Epoch 106/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2995 - acc: 0.8888 - val_loss: 1.8086 - val_acc: 0.6180
#
# Epoch 00106: val_acc did not improve from 0.72135
# Epoch 107/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2466 - acc: 0.9101 - val_loss: 1.7086 - val_acc: 0.6360
#
# Epoch 00107: val_acc did not improve from 0.72135
# Epoch 108/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2716 - acc: 0.8983 - val_loss: 1.7379 - val_acc: 0.6494
#
# Epoch 00108: val_acc did not improve from 0.72135
# Epoch 109/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3074 - acc: 0.8860 - val_loss: 1.8191 - val_acc: 0.6225
#
# Epoch 00109: val_acc did not improve from 0.72135
# Epoch 110/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3000 - acc: 0.8871 - val_loss: 1.7193 - val_acc: 0.6719
#
# Epoch 00110: val_acc did not improve from 0.72135
# Epoch 111/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2200 - acc: 0.9101 - val_loss: 1.6606 - val_acc: 0.6787
#
# Epoch 00111: val_acc did not improve from 0.72135
# Epoch 112/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1954 - acc: 0.9264 - val_loss: 1.8545 - val_acc: 0.6764
#
# Epoch 00112: val_acc did not improve from 0.72135
# Epoch 113/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2483 - acc: 0.9006 - val_loss: 1.7908 - val_acc: 0.6180
#
# Epoch 00113: val_acc did not improve from 0.72135
# Epoch 114/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2411 - acc: 0.9101 - val_loss: 1.6865 - val_acc: 0.6966
#
# Epoch 00114: val_acc did not improve from 0.72135
# Epoch 115/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1769 - acc: 0.9404 - val_loss: 1.8857 - val_acc: 0.6652
#
# Epoch 00115: val_acc did not improve from 0.72135
# Epoch 116/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1844 - acc: 0.9281 - val_loss: 1.8630 - val_acc: 0.6831
#
# Epoch 00116: val_acc did not improve from 0.72135
# Epoch 117/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1862 - acc: 0.9292 - val_loss: 1.8813 - val_acc: 0.6697
#
# Epoch 00117: val_acc did not improve from 0.72135
# Epoch 118/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1754 - acc: 0.9320 - val_loss: 1.8588 - val_acc: 0.6854
#
# Epoch 00118: val_acc did not improve from 0.72135
# Epoch 119/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1659 - acc: 0.9444 - val_loss: 1.8662 - val_acc: 0.6831
#
# Epoch 00119: val_acc did not improve from 0.72135
# Epoch 120/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1450 - acc: 0.9438 - val_loss: 1.8563 - val_acc: 0.6876
#
# Epoch 00120: val_acc did not improve from 0.72135
# Epoch 121/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1296 - acc: 0.9517 - val_loss: 1.9196 - val_acc: 0.6854
#
# Epoch 00121: val_acc did not improve from 0.72135
# Epoch 122/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1789 - acc: 0.9247 - val_loss: 1.9657 - val_acc: 0.6629
#
# Epoch 00122: val_acc did not improve from 0.72135
# Epoch 123/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1894 - acc: 0.9292 - val_loss: 1.9825 - val_acc: 0.6921
#
# Epoch 00123: val_acc did not improve from 0.72135
# Epoch 124/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1692 - acc: 0.9348 - val_loss: 1.8989 - val_acc: 0.6831
#
# Epoch 00124: val_acc did not improve from 0.72135
# Epoch 125/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1503 - acc: 0.9388 - val_loss: 1.9555 - val_acc: 0.6742
#
# Epoch 00125: val_acc did not improve from 0.72135
# Epoch 126/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1595 - acc: 0.9438 - val_loss: 1.9595 - val_acc: 0.6989
#
# Epoch 00126: val_acc did not improve from 0.72135
# Epoch 127/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1505 - acc: 0.9444 - val_loss: 2.0318 - val_acc: 0.6989
#
# Epoch 00127: val_acc did not improve from 0.72135
# Epoch 128/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1324 - acc: 0.9545 - val_loss: 2.0468 - val_acc: 0.6742
#
# Epoch 00128: val_acc did not improve from 0.72135
# Epoch 129/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1262 - acc: 0.9517 - val_loss: 2.0970 - val_acc: 0.6876
#
# Epoch 00129: val_acc did not improve from 0.72135
# Epoch 130/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1253 - acc: 0.9522 - val_loss: 2.0106 - val_acc: 0.6944
#
# Epoch 00130: val_acc did not improve from 0.72135
# Epoch 131/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1207 - acc: 0.9590 - val_loss: 2.1436 - val_acc: 0.6831
#
# Epoch 00131: val_acc did not improve from 0.72135
# Epoch 132/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1314 - acc: 0.9466 - val_loss: 2.1077 - val_acc: 0.6989
#
# Epoch 00132: val_acc did not improve from 0.72135
# Epoch 133/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1249 - acc: 0.9522 - val_loss: 2.1807 - val_acc: 0.6921
#
# Epoch 00133: val_acc did not improve from 0.72135
# Epoch 134/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1153 - acc: 0.9562 - val_loss: 2.1170 - val_acc: 0.6764
#
# Epoch 00134: val_acc did not improve from 0.72135
# Epoch 135/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1666 - acc: 0.9343 - val_loss: 2.1811 - val_acc: 0.6607
#
# Epoch 00135: val_acc did not improve from 0.72135
# Epoch 136/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1683 - acc: 0.9382 - val_loss: 2.0248 - val_acc: 0.6854
#
# Epoch 00136: val_acc did not improve from 0.72135
# Epoch 137/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1600 - acc: 0.9365 - val_loss: 2.1330 - val_acc: 0.6517
#
# Epoch 00137: val_acc did not improve from 0.72135
# Epoch 138/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1558 - acc: 0.9320 - val_loss: 2.0989 - val_acc: 0.6809
#
# Epoch 00138: val_acc did not improve from 0.72135
# Epoch 139/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1558 - acc: 0.9354 - val_loss: 2.3359 - val_acc: 0.6337
#
# Epoch 00139: val_acc did not improve from 0.72135
# Epoch 140/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2107 - acc: 0.9247 - val_loss: 2.2030 - val_acc: 0.6247
#
# Epoch 00140: val_acc did not improve from 0.72135
# Epoch 141/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2302 - acc: 0.9096 - val_loss: 2.0962 - val_acc: 0.6315
#
# Epoch 00141: val_acc did not improve from 0.72135
# Epoch 142/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2143 - acc: 0.9090 - val_loss: 2.5414 - val_acc: 0.6270
#
# Epoch 00142: val_acc did not improve from 0.72135
# Epoch 143/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3179 - acc: 0.8747 - val_loss: 2.2032 - val_acc: 0.6382
#
# Epoch 00143: val_acc did not improve from 0.72135
# Epoch 144/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2971 - acc: 0.8848 - val_loss: 2.0321 - val_acc: 0.6000
#
# Epoch 00144: val_acc did not improve from 0.72135
# Epoch 145/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.3336 - acc: 0.8669 - val_loss: 2.0253 - val_acc: 0.6247
#
# Epoch 00145: val_acc did not improve from 0.72135
# Epoch 146/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2691 - acc: 0.8955 - val_loss: 1.9855 - val_acc: 0.6337
#
# Epoch 00146: val_acc did not improve from 0.72135
# Epoch 147/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2265 - acc: 0.9236 - val_loss: 2.0415 - val_acc: 0.6472
#
# Epoch 00147: val_acc did not improve from 0.72135
# Epoch 148/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2153 - acc: 0.9169 - val_loss: 2.0802 - val_acc: 0.6404
#
# Epoch 00148: val_acc did not improve from 0.72135
# Epoch 149/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.2227 - acc: 0.9180 - val_loss: 2.0715 - val_acc: 0.6584
#
# Epoch 00149: val_acc did not improve from 0.72135
# Epoch 150/150
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.1991 - acc: 0.9197 - val_loss: 2.1599 - val_acc: 0.6270
#
# Epoch 00150: val_acc did not improve from 0.72135
# Duration: 0:17:21.680076

# %%
def plot_history(hist):
    #print(hist.history.keys())

    # 精度の履歴をプロット
    plt.plot(hist.history['acc'])
    plt.plot(hist.history['val_acc'])
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(['acc', 'val_acc'], loc='upper left')
    plt.show()

    # 損失の履歴をプロット
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['loss', 'val_loss'], loc='upper left')
    plt.show()

# 学習履歴をプロット
plot_history(hist)

# %%
# モデルの設定

model = load_model("model.h5")

# %%
#ytest = np.array(y_test)
ytest = np.argmax(y_test, axis=1)
pd = model.predict(X_test)
prediction = pd.argmax(1)

# %%
from sklearn.metrics import classification_report, confusion_matrix

#ytest = np.array(y_test)
ytest = np.argmax(y_test, axis=1)
pd = model.predict(X_test)
prediction = pd.argmax(1)


# confusion matrix and classification report(precision, recall, F1-score)
print(classification_report(ytest, prediction))
print(confusion_matrix(ytest, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.64      0.64        84
#            1       0.77      0.69      0.73        77
#            2       0.75      0.67      0.70       102
#            3       0.67      0.78      0.72        80
#            4       0.79      0.82      0.81       102
#
#     accuracy                           0.72       445
#    macro avg       0.72      0.72      0.72       445
# weighted avg       0.72      0.72      0.72       445
#
# [[54  8  9  8  5]
#  [ 3 53  3  9  9]
#  [11  4 68 13  6]
#  [ 7  1  8 62  2]
#  [11  3  3  1 84]]

# %%
from sklearn.metrics import accuracy_score


accuracy = accuracy_score(ytest, prediction)
accuracy
# Out:
# 0.7213483146067415

# %% [markdown]
# ## 4. 推論

# %%
# 推論のスクリプト

def predictions(text):
  clean = re.sub(r'[^ a-z A-Z 0-9]', " ", text)
  test_word = word_tokenize(clean)
  test_word = [w.lower() for w in test_word]
  test_ls = word_tokenizer.texts_to_sequences(test_word)
  print(test_word)
  #Check for unknown words
  if [] in test_ls:
    test_ls = list(filter(None, test_ls))
    
  test_ls = np.array(test_ls).reshape(1, len(test_ls))
 
  x = padding_doc(test_ls, max_length)
  
  pred = model.predict_proba(x)
  
  return pred


def get_final_output(pred, classes):
  predictions = pred[0]
 
  classes = np.array(classes)
  ids = np.argsort(-predictions)
  classes = classes[ids]
  predictions = -np.sort(-predictions)
 
  for i in range(pred.shape[1]):
    print("%s has confidence = %s" % (classes[i], (predictions[i])))

# %%
# テスト

text = "European Championships: GB women reach wheelchair basketball final for first time"
pred = predictions(text)
get_final_output(pred, unique_category)
# Out:
# ['european', 'championships', 'gb', 'women', 'reach', 'wheelchair', 'basketball', 'final', 'for', 'first', 'time']
# sport has confidence = 0.99943954
# entertainment has confidence = 0.00033313312
# business has confidence = 0.00016143131
# politics has confidence = 6.578676e-05
# tech has confidence = 4.03346e-08
