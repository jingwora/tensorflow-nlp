# %% [markdown]
# # LSTM Intent Classification
# ---
# **Dataset:** bbc news (2225 samples) News contents with 5 categories (Sport, Business, Politics, Tech and Others)
#
# **Model:**   multiclass classification model : LSTM
#
# **Training:**  Colab (GPU)
#
# **Process:**  1. Dataset Load  ➔ 2. Data processing ➔ 3. Model Training  ➔ 4. Model Evaluation ➔ 5. Prediction
#
# **Result:**  Accuracy = 0.63, run time = 9 minutes

# %% [markdown]
# ## ライブラリ

# %%
#　ライブラリ

import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
import nltk
import re
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Bidirectional, Embedding, Dropout
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1. データ読み込

# %%
# google driveと接続

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# intent, unique_intent, sentencesに分ける

def load_dataset(filename):
  df = pd.read_csv(filename, encoding = "latin1", header=0)
  print(df.head())
  category = df["category"]
  unique_category = list(set(category))
  text = list(df["text"])
  
  return (df, category, unique_category, text)

# %%
# データ読み込

dataset = "/content/drive/My Drive/dataset/bbc/bbc-text.csv"
df, category, unique_category, text = load_dataset(dataset)
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
import matplotlib.pyplot as plt

df.groupby('category').text.count().plot.bar(ylim=0)
plt.show()

# %%
# サンプルデータを確認

print(text[:5])
# Out:
# ['tv future in the hands of viewers with home theatre systems  plasma high-definition tvs  and digital video recorders moving into the living room  the way people watch tv will be radically different in five years  time.  that is according to an expert panel which gathered at the annual consumer electronics show in las vegas to discuss how these new technologies will impact one of our favourite pastimes. with the us leading the trend  programmes and other content will be delivered to viewers via home networks  through cable  satellite  telecoms companies  and broadband service providers to front rooms and portable devices.  one of the most talked-about technologies of ces has been digital and personal video recorders (dvr and pvr). these set-top boxes  like the us s tivo and the uk s sky+ system  allow people to record  store  play  pause and forward wind tv programmes when they want.  essentially  the technology allows for much more personalised tv. they are also being built-in to high-definition tv sets  which are big business in japan and the us  but slower to take off in europe because of the lack of high-definition programming. not only can people forward wind through adverts  they can also forget about abiding by network and channel schedules  putting together their own a-la-carte entertainment. but some us networks and cable and satellite companies are worried about what it means for them in terms of advertising revenues as well as  brand identity  and viewer loyalty to channels. although the us leads in this technology at the moment  it is also a concern that is being raised in europe  particularly with the growing uptake of services like sky+.  what happens here today  we will see in nine months to a years  time in the uk   adam hume  the bbc broadcast s futurologist told the bbc news website. for the likes of the bbc  there are no issues of lost advertising revenue yet. it is a more pressing issue at the moment for commercial uk broadcasters  but brand loyalty is important for everyone.  we will be talking more about content brands rather than network brands   said tim hanlon  from brand communications firm starcom mediavest.  the reality is that with broadband connections  anybody can be the producer of content.  he added:  the challenge now is that it is hard to promote a programme with so much choice.   what this means  said stacey jolna  senior vice president of tv guide tv group  is that the way people find the content they want to watch has to be simplified for tv viewers. it means that networks  in us terms  or channels could take a leaf out of google s book and be the search engine of the future  instead of the scheduler to help people find what they want to watch. this kind of channel model might work for the younger ipod generation which is used to taking control of their gadgets and what they play on them. but it might not suit everyone  the panel recognised. older generations are more comfortable with familiar schedules and channel brands because they know what they are getting. they perhaps do not want so much of the choice put into their hands  mr hanlon suggested.  on the other end  you have the kids just out of diapers who are pushing buttons already - everything is possible and available to them   said mr hanlon.  ultimately  the consumer will tell the market they want.   of the 50 000 new gadgets and technologies being showcased at ces  many of them are about enhancing the tv-watching experience. high-definition tv sets are everywhere and many new models of lcd (liquid crystal display) tvs have been launched with dvr capability built into them  instead of being external boxes. one such example launched at the show is humax s 26-inch lcd tv with an 80-hour tivo dvr and dvd recorder. one of the us s biggest satellite tv companies  directtv  has even launched its own branded dvr at the show with 100-hours of recording capability  instant replay  and a search function. the set can pause and rewind tv fo ...

# %% [markdown]
# ## 2. データ準備

# %%
# nltkのstopwordsとtokenizersを読み込む

nltk.download("stopwords")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#define stemmer
stemmer = LancasterStemmer()

# %%
# データクリーニング

def cleaning(text):
  words = []
  for s in text:
    clean = re.sub(r'[^ a-z A-Z 0-9]', " ", s)
    w = word_tokenize(clean)
    #stemming
    words.append([i.lower() for i in w])
    
  return words

cleaned_words = cleaning(text)
print(len(cleaned_words))
print(cleaned_words[:2])
# Out:
# 2225
# [['tv', 'future', 'in', 'the', 'hands', 'of', 'viewers', 'with', 'home', 'theatre', 'systems', 'plasma', 'high', 'definition', 'tvs', 'and', 'digital', 'video', 'recorders', 'moving', 'into', 'the', 'living', 'room', 'the', 'way', 'people', 'watch', 'tv', 'will', 'be', 'radically', 'different', 'in', 'five', 'years', 'time', 'that', 'is', 'according', 'to', 'an', 'expert', 'panel', 'which', 'gathered', 'at', 'the', 'annual', 'consumer', 'electronics', 'show', 'in', 'las', 'vegas', 'to', 'discuss', 'how', 'these', 'new', 'technologies', 'will', 'impact', 'one', 'of', 'our', 'favourite', 'pastimes', 'with', 'the', 'us', 'leading', 'the', 'trend', 'programmes', 'and', 'other', 'content', 'will', 'be', 'delivered', 'to', 'viewers', 'via', 'home', 'networks', 'through', 'cable', 'satellite', 'telecoms', 'companies', 'and', 'broadband', 'service', 'providers', 'to', 'front', 'rooms', 'and', 'portable', 'devices', 'one', 'of', 'the', 'most', 'talked', 'about', 'technologies', 'of', 'ces', 'has', 'been', 'digital', 'and', 'personal', 'video', 'recorders', 'dvr', 'and', 'pvr', 'these', 'set', 'top', 'boxes', 'like', 'the', 'us', 's', 'tivo', 'and', 'the', 'uk', 's', 'sky', 'system', 'allow', 'people', 'to', 'record', 'store', 'play', 'pause', 'and', 'forward', 'wind', 'tv', 'programmes', 'when', 'they', 'want', 'essentially', 'the', 'technology', 'allows', 'for', 'much', 'more', 'personalised', 'tv', 'they', 'are', 'also', 'being', 'built', 'in', 'to', 'high', 'definition', 'tv', 'sets', 'which', 'are', 'big', 'business', 'in', 'japan', 'and', 'the', 'us', 'but', 'slower', 'to', 'take', 'off', 'in', 'europe', 'because', 'of', 'the', 'lack', 'of', 'high', 'definition', 'programming', 'not', 'only', 'can', 'people', 'forward', 'wind', 'through', 'adverts', 'they', 'can', 'also', 'forget', 'about', 'abiding', 'by', 'network', 'and', 'channel', 'schedules', 'putting', 'together', 'their', 'own', 'a', 'la', 'carte', 'entertainment', 'but', 'some', 'us', 'networks', 'and', 'cable', 'and', 'satellite', 'companies', 'are', 'worried', 'about', 'what', 'it', 'means', 'for', 'them', 'in', 'terms', 'of', 'advertising', 'revenues', 'as', 'well', 'as', 'brand', 'identity', 'and', 'viewer', 'loyalty', 'to', 'channels', 'although', 'the', 'us', 'leads', 'in', 'this', 'technology', 'at', 'the', 'moment', 'it', 'is', 'also', 'a', 'concern', 'that', 'is', 'being', 'raised', 'in', 'europe', 'particularly', 'with', 'the', 'growing', 'uptake', 'of', 'services', 'like', 'sky', 'what', 'happens', 'here', 'today', 'we', 'will', 'see', 'in', 'nine', 'months', 'to', 'a', 'years', 'time', 'in', 'the', 'uk', 'adam', 'hume', 'the', 'bbc', 'broadcast', 's', 'futurologist', 'told', 'the', 'bbc', 'news', 'website', 'for', 'the', 'likes', 'of', 'the', 'bbc', 'there', 'are', 'no', 'issues', 'of', 'lost', 'advertising', 'revenue', 'yet', 'it', 'is', 'a', 'more', 'pressing', 'issue', 'at', 'the', 'moment', 'for', 'commercial', 'uk', 'broadcasters', 'but', 'brand', 'loyalty', 'is', 'important', 'for', 'everyone', 'we', 'will', 'be', 'talking', 'more', 'about', 'content', 'brands', 'rather', 'than', 'network', 'brands', 'said', 'tim', 'hanlon', 'from', 'brand', 'communications', 'firm', 'starcom', 'mediavest', 'the', 'reality', 'is', 'that', 'with', 'broadband', 'connections', 'anybody', 'can', 'be', 'the', 'producer', 'of', 'content', 'he', 'added', 'the', 'challenge', 'now', 'is', 'that', 'it', 'is', 'hard', 'to', 'promote', 'a', 'programme', 'with', 'so', 'much', 'choice', 'what', 'this', 'means', 'said', 'stacey', 'jolna', 'senior', 'vice', 'president', 'of', 'tv', 'guide', 'tv', 'group', 'is', 'that', 'the', 'way', 'people', 'find', 'the', 'content', 'they', 'want', 'to', 'watch', 'has', 'to', 'be', 'simplified', 'for', 'tv', 'viewers', 'it', 'means', 'that', 'networks', 'in', 'us', 'terms', 'or', 'channels', 'could', 'take', 'a', 'leaf', 'out', 'of', 'google', 's', 'book', 'and', 'be', 'the', 'search', 'engine', 'of', 'the', 'future', 'instead', 'of', 'the', 'schedule ...

# %%
# Tokenizerを作成

def create_tokenizer(words, filters = '!"#$%&()*+,-./:;<=>?@[\]^_`{|}~'):
  token = Tokenizer(filters = filters)
  token.fit_on_texts(words)
  return token

# max_lengthの設定
def max_length(words):
  return(len(max(words, key = len)))


word_tokenizer = create_tokenizer(cleaned_words)
vocab_size = len(word_tokenizer.word_index) + 1
# max_length = max_length(cleaned_words)
max_length = 250

print("Vocab Size = %d and Maximum length = %d" % (vocab_size, max_length))
# Out:
# Vocab Size = 29457 and Maximum length = 250

# %%
def encoding_doc(token, words):
  return(token.texts_to_sequences(words))

encoded_doc = encoding_doc(word_tokenizer, cleaned_words)

def padding_doc(encoded_doc, max_length):
  return(pad_sequences(encoded_doc, maxlen = max_length, padding = "post"))

padded_doc = padding_doc(encoded_doc, max_length)

# %%
padded_doc[:5]
# Out:
# array([[   11,   465,    27, ...,    66,    29,   166],
#        [ 1709,     7,   481, ...,  2480,    30,  7014],
#        [ 5058,  7015,     3, ...,  1968,     0,     0],
#        [ 5276,     2,     5, ...,   421,   474,   325],
#        [ 5277,  3133,    19, ...,  2305, 14956, 12596]], dtype=int32)

# %%
print("Shape of padded docs = ",padded_doc.shape)
# Out:
# Shape of padded docs =  (2225, 250)

# %%
# tokenizer with filter changed
output_tokenizer = create_tokenizer(unique_category, filters = '!"#$%&()*+,-/:;<=>?@[\]^`{|}~')

# %%
output_tokenizer.word_index
# Out:
# {'business': 3, 'entertainment': 2, 'politics': 5, 'sport': 1, 'tech': 4}

# %%
# Tokenizer

encoded_output = encoding_doc(output_tokenizer, category)

encoded_output = np.array(encoded_output).reshape(len(encoded_output), 1)

encoded_output.shape
# Out:
# (2225, 1)

# %%
# one hot encoder

def one_hot(encode):
  o = OneHotEncoder(sparse = False)
  return(o.fit_transform(encode))

output_one_hot = one_hot(encoded_output)

output_one_hot.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# (2225, 5)

# %%
# 学習とテストを分ける

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(padded_doc, output_one_hot, shuffle = True,  stratify = category, test_size = 0.2, random_state=11)

print("Shape of X_train = %s and y_train = %s" % (X_train.shape, y_train.shape))
print("Shape of X_test = %s and y_test = %s" % (X_test.shape, y_test.shape))
# Out:
# Shape of X_train = (1780, 250) and y_train = (1780, 5)
# Shape of X_test = (445, 250) and y_test = (445, 5)

# %% [markdown]
# ## 3. 学習

# %%
# モデルの設定

def create_model(vocab_size, max_length):
  model = Sequential()
  model.add(Embedding(vocab_size, 128, input_length = max_length, trainable = False))
  model.add(Bidirectional(LSTM(128)))
#   model.add(LSTM(128))
  model.add(Dense(32, activation = "relu"))
  model.add(Dropout(0.65))
  model.add(Dense(5, activation = "softmax"))
  
  return model

model = create_model(vocab_size, max_length)

model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0725 05:33:09.062433 140698915252096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0725 05:33:09.080427 140698915252096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0725 05:33:09.082474 140698915252096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0725 05:33:09.654319 140698915252096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0725 05:33:09.665169 140698915252096 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0725 05:33:09.667673 140698915252096 nn_ops.py:4224] Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# W0725 05:33:09.695227 140698915252096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0725 05:33:09.719691 140698915252096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 250, 128)          3770496
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               263168
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 4,042,053
# Trainable params: 271,557
# Non-trainable params: 3,770,496
# _________________________________________________________________

# %%
# モデル学習
from datetime import datetime

start_time = datetime.now()

filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

hist = model.fit(X_train, y_train, epochs = 180, batch_size = 250, validation_data = (X_test, y_test), callbacks = [checkpoint])

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Train on 1780 samples, validate on 445 samples
# Epoch 1/180
# 1780/1780 [==============================] - 8s 4ms/step - loss: 0.7197 - acc: 0.7539 - val_loss: 0.9272 - val_acc: 0.6584
#
# Epoch 00001: val_acc improved from -inf to 0.65843, saving model to model.h5
# Epoch 2/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6951 - acc: 0.7669 - val_loss: 1.1322 - val_acc: 0.6112
#
# Epoch 00002: val_acc did not improve from 0.65843
# Epoch 3/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.8544 - acc: 0.7135 - val_loss: 1.1295 - val_acc: 0.5798
#
# Epoch 00003: val_acc did not improve from 0.65843
# Epoch 4/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.7915 - acc: 0.7174 - val_loss: 1.1005 - val_acc: 0.6315
#
# Epoch 00004: val_acc did not improve from 0.65843
# Epoch 5/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.7661 - acc: 0.7281 - val_loss: 1.0092 - val_acc: 0.6225
#
# Epoch 00005: val_acc did not improve from 0.65843
# Epoch 6/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.7604 - acc: 0.7303 - val_loss: 0.9765 - val_acc: 0.6494
#
# Epoch 00006: val_acc did not improve from 0.65843
# Epoch 7/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.7017 - acc: 0.7494 - val_loss: 1.0557 - val_acc: 0.6382
#
# Epoch 00007: val_acc did not improve from 0.65843
# Epoch 8/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.7021 - acc: 0.7478 - val_loss: 1.1779 - val_acc: 0.6022
#
# Epoch 00008: val_acc did not improve from 0.65843
# Epoch 9/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6960 - acc: 0.7539 - val_loss: 1.0866 - val_acc: 0.6360
#
# Epoch 00009: val_acc did not improve from 0.65843
# Epoch 10/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6950 - acc: 0.7635 - val_loss: 1.1253 - val_acc: 0.5933
#
# Epoch 00010: val_acc did not improve from 0.65843
# Epoch 11/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.9711 - acc: 0.6140 - val_loss: 1.4129 - val_acc: 0.5551
#
# Epoch 00011: val_acc did not improve from 0.65843
# Epoch 12/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 1.0972 - acc: 0.5876 - val_loss: 1.2748 - val_acc: 0.5326
#
# Epoch 00012: val_acc did not improve from 0.65843
# Epoch 13/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.9303 - acc: 0.6640 - val_loss: 1.1929 - val_acc: 0.5708
#
# Epoch 00013: val_acc did not improve from 0.65843
# Epoch 14/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.8096 - acc: 0.7011 - val_loss: 1.0481 - val_acc: 0.6270
#
# Epoch 00014: val_acc did not improve from 0.65843
# Epoch 15/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.7896 - acc: 0.7000 - val_loss: 1.0610 - val_acc: 0.6360
#
# Epoch 00015: val_acc did not improve from 0.65843
# Epoch 16/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.7448 - acc: 0.7157 - val_loss: 1.0332 - val_acc: 0.6337
#
# Epoch 00016: val_acc did not improve from 0.65843
# Epoch 17/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.7271 - acc: 0.7455 - val_loss: 1.0042 - val_acc: 0.6360
#
# Epoch 00017: val_acc did not improve from 0.65843
# Epoch 18/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.7025 - acc: 0.7601 - val_loss: 1.0119 - val_acc: 0.6449
#
# Epoch 00018: val_acc did not improve from 0.65843
# Epoch 19/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6821 - acc: 0.7545 - val_loss: 1.0053 - val_acc: 0.6607
#
# Epoch 00019: val_acc improved from 0.65843 to 0.66067, saving model to model.h5
# Epoch 20/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6481 - acc: 0.7657 - val_loss: 1.0167 - val_acc: 0.6539
#
# Epoch 00020: val_acc did not improve from 0.66067
# Epoch 21/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.6226 - acc: 0.7775 - val_loss: 1.0014 - val_acc: 0.6787
#
# Epoch 00021: val_acc improved from 0.66067 to 0.67865, saving model to model.h5
# Epoch 22/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6237 - acc: 0.7910 - val_loss: 1.0235 - val_acc: 0.6674
#
# Epoch 00022: val_acc did not improve from 0.67865
# Epoch 23/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6050 - acc: 0.7758 - val_loss: 1.2034 - val_acc: 0.6270
#
# Epoch 00023: val_acc did not improve from 0.67865
# Epoch 24/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.6836 - acc: 0.7545 - val_loss: 1.0614 - val_acc: 0.6652
#
# Epoch 00024: val_acc did not improve from 0.67865
# Epoch 25/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6019 - acc: 0.7904 - val_loss: 1.0218 - val_acc: 0.6674
#
# Epoch 00025: val_acc did not improve from 0.67865
# Epoch 26/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6043 - acc: 0.7803 - val_loss: 1.0109 - val_acc: 0.6539
#
# Epoch 00026: val_acc did not improve from 0.67865
# Epoch 27/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.5890 - acc: 0.8084 - val_loss: 1.0330 - val_acc: 0.6742
#
# Epoch 00027: val_acc did not improve from 0.67865
# Epoch 28/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.5505 - acc: 0.8152 - val_loss: 1.0708 - val_acc: 0.6607
#
# Epoch 00028: val_acc did not improve from 0.67865
# Epoch 29/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.6237 - acc: 0.7730 - val_loss: 1.3678 - val_acc: 0.5888
#
# Epoch 00029: val_acc did not improve from 0.67865
# Epoch 30/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.6747 - acc: 0.7522 - val_loss: 1.1392 - val_acc: 0.6112
#
# Epoch 00030: val_acc did not improve from 0.67865
# Epoch 31/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.6464 - acc: 0.7607 - val_loss: 0.9934 - val_acc: 0.6562
#
# Epoch 00031: val_acc did not improve from 0.67865
# Epoch 32/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5818 - acc: 0.8000 - val_loss: 1.0431 - val_acc: 0.6472
#
# Epoch 00032: val_acc did not improve from 0.67865
# Epoch 33/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5559 - acc: 0.8028 - val_loss: 1.0391 - val_acc: 0.6607
#
# Epoch 00033: val_acc did not improve from 0.67865
# Epoch 34/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5953 - acc: 0.7854 - val_loss: 0.9803 - val_acc: 0.6607
#
# Epoch 00034: val_acc did not improve from 0.67865
# Epoch 35/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6099 - acc: 0.7848 - val_loss: 0.9879 - val_acc: 0.6787
#
# Epoch 00035: val_acc improved from 0.67865 to 0.67865, saving model to model.h5
# Epoch 36/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.5378 - acc: 0.8096 - val_loss: 1.0487 - val_acc: 0.6539
#
# Epoch 00036: val_acc did not improve from 0.67865
# Epoch 37/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5263 - acc: 0.8152 - val_loss: 0.9716 - val_acc: 0.6719
#
# Epoch 00037: val_acc did not improve from 0.67865
# Epoch 38/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5142 - acc: 0.8157 - val_loss: 1.0633 - val_acc: 0.6742
#
# Epoch 00038: val_acc did not improve from 0.67865
# Epoch 39/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5222 - acc: 0.8264 - val_loss: 1.0282 - val_acc: 0.6809
#
# Epoch 00039: val_acc improved from 0.67865 to 0.68090, saving model to model.h5
# Epoch 40/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5341 - acc: 0.8152 - val_loss: 1.1400 - val_acc: 0.6360
#
# Epoch 00040: val_acc did not improve from 0.68090
# Epoch 41/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.6834 - acc: 0.7337 - val_loss: 1.5974 - val_acc: 0.5303
#
# Epoch 00041: val_acc did not improve from 0.68090
# Epoch 42/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.7060 - acc: 0.7567 - val_loss: 1.0638 - val_acc: 0.6360
#
# Epoch 00042: val_acc did not improve from 0.68090
# Epoch 43/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.6161 - acc: 0.7843 - val_loss: 1.0197 - val_acc: 0.6674
#
# Epoch 00043: val_acc did not improve from 0.68090
# Epoch 44/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5559 - acc: 0.8129 - val_loss: 1.1052 - val_acc: 0.6337
#
# Epoch 00044: val_acc did not improve from 0.68090
# Epoch 45/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5633 - acc: 0.8011 - val_loss: 0.9691 - val_acc: 0.6764
#
# Epoch 00045: val_acc did not improve from 0.68090
# Epoch 46/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5378 - acc: 0.8096 - val_loss: 1.0689 - val_acc: 0.6337
#
# Epoch 00046: val_acc did not improve from 0.68090
# Epoch 47/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5616 - acc: 0.8112 - val_loss: 1.0522 - val_acc: 0.6494
#
# Epoch 00047: val_acc did not improve from 0.68090
# Epoch 48/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.6113 - acc: 0.7966 - val_loss: 1.0183 - val_acc: 0.6449
#
# Epoch 00048: val_acc did not improve from 0.68090
# Epoch 49/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.5452 - acc: 0.8118 - val_loss: 1.0495 - val_acc: 0.6539
#
# Epoch 00049: val_acc did not improve from 0.68090
# Epoch 50/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5374 - acc: 0.8140 - val_loss: 1.0735 - val_acc: 0.6494
#
# Epoch 00050: val_acc did not improve from 0.68090
# Epoch 51/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5235 - acc: 0.8236 - val_loss: 1.0269 - val_acc: 0.6697
#
# Epoch 00051: val_acc did not improve from 0.68090
# Epoch 52/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5913 - acc: 0.7770 - val_loss: 1.1611 - val_acc: 0.6247
#
# Epoch 00052: val_acc did not improve from 0.68090
# Epoch 53/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5460 - acc: 0.8118 - val_loss: 1.1226 - val_acc: 0.6225
#
# Epoch 00053: val_acc did not improve from 0.68090
# Epoch 54/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5044 - acc: 0.8180 - val_loss: 1.0716 - val_acc: 0.6494
#
# Epoch 00054: val_acc did not improve from 0.68090
# Epoch 55/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4753 - acc: 0.8472 - val_loss: 1.3126 - val_acc: 0.6337
#
# Epoch 00055: val_acc did not improve from 0.68090
# Epoch 56/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5648 - acc: 0.8011 - val_loss: 1.0834 - val_acc: 0.6382
#
# Epoch 00056: val_acc did not improve from 0.68090
# Epoch 57/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4885 - acc: 0.8348 - val_loss: 1.0951 - val_acc: 0.6539
#
# Epoch 00057: val_acc did not improve from 0.68090
# Epoch 58/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.5187 - acc: 0.8197 - val_loss: 1.1211 - val_acc: 0.6697
#
# Epoch 00058: val_acc did not improve from 0.68090
# Epoch 59/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4733 - acc: 0.8399 - val_loss: 1.1690 - val_acc: 0.6472
#
# Epoch 00059: val_acc did not improve from 0.68090
# Epoch 60/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4418 - acc: 0.8522 - val_loss: 1.2347 - val_acc: 0.6517
#
# Epoch 00060: val_acc did not improve from 0.68090
# Epoch 61/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.4705 - acc: 0.8331 - val_loss: 1.1199 - val_acc: 0.6360
#
# Epoch 00061: val_acc did not improve from 0.68090
# Epoch 62/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4827 - acc: 0.8354 - val_loss: 1.1390 - val_acc: 0.6472
#
# Epoch 00062: val_acc did not improve from 0.68090
# Epoch 63/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4324 - acc: 0.8517 - val_loss: 1.1732 - val_acc: 0.6697
#
# Epoch 00063: val_acc did not improve from 0.68090
# Epoch 64/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4311 - acc: 0.8562 - val_loss: 1.2012 - val_acc: 0.6764
#
# Epoch 00064: val_acc did not improve from 0.68090
# Epoch 65/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4054 - acc: 0.8601 - val_loss: 1.3075 - val_acc: 0.6629
#
# Epoch 00065: val_acc did not improve from 0.68090
# Epoch 66/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4284 - acc: 0.8483 - val_loss: 1.2084 - val_acc: 0.6674
#
# Epoch 00066: val_acc did not improve from 0.68090
# Epoch 67/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.4138 - acc: 0.8472 - val_loss: 1.2606 - val_acc: 0.6315
#
# Epoch 00067: val_acc did not improve from 0.68090
# Epoch 68/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4686 - acc: 0.8360 - val_loss: 1.1735 - val_acc: 0.6404
#
# Epoch 00068: val_acc did not improve from 0.68090
# Epoch 69/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4151 - acc: 0.8601 - val_loss: 1.0735 - val_acc: 0.6697
#
# Epoch 00069: val_acc did not improve from 0.68090
# Epoch 70/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4100 - acc: 0.8624 - val_loss: 1.0388 - val_acc: 0.6674
#
# Epoch 00070: val_acc did not improve from 0.68090
# Epoch 71/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3873 - acc: 0.8742 - val_loss: 1.1494 - val_acc: 0.6562
#
# Epoch 00071: val_acc did not improve from 0.68090
# Epoch 72/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.4260 - acc: 0.8551 - val_loss: 1.1663 - val_acc: 0.6719
#
# Epoch 00072: val_acc did not improve from 0.68090
# Epoch 73/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3866 - acc: 0.8764 - val_loss: 1.1885 - val_acc: 0.6562
#
# Epoch 00073: val_acc did not improve from 0.68090
# Epoch 74/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3876 - acc: 0.8669 - val_loss: 1.0986 - val_acc: 0.6831
#
# Epoch 00074: val_acc improved from 0.68090 to 0.68315, saving model to model.h5
# Epoch 75/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3604 - acc: 0.8803 - val_loss: 1.1809 - val_acc: 0.6742
#
# Epoch 00075: val_acc did not improve from 0.68315
# Epoch 76/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3705 - acc: 0.8719 - val_loss: 1.2496 - val_acc: 0.6517
#
# Epoch 00076: val_acc did not improve from 0.68315
# Epoch 77/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3976 - acc: 0.8539 - val_loss: 1.2131 - val_acc: 0.6562
#
# Epoch 00077: val_acc did not improve from 0.68315
# Epoch 78/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3536 - acc: 0.8770 - val_loss: 1.1984 - val_acc: 0.6517
#
# Epoch 00078: val_acc did not improve from 0.68315
# Epoch 79/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3868 - acc: 0.8612 - val_loss: 1.2373 - val_acc: 0.6787
#
# Epoch 00079: val_acc did not improve from 0.68315
# Epoch 80/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3813 - acc: 0.8747 - val_loss: 1.2761 - val_acc: 0.6697
#
# Epoch 00080: val_acc did not improve from 0.68315
# Epoch 81/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3339 - acc: 0.8871 - val_loss: 1.2710 - val_acc: 0.6517
#
# Epoch 00081: val_acc did not improve from 0.68315
# Epoch 82/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3234 - acc: 0.8927 - val_loss: 1.3116 - val_acc: 0.6629
#
# Epoch 00082: val_acc did not improve from 0.68315
# Epoch 83/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3535 - acc: 0.8747 - val_loss: 1.2909 - val_acc: 0.6652
#
# Epoch 00083: val_acc did not improve from 0.68315
# Epoch 84/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3935 - acc: 0.8612 - val_loss: 1.2039 - val_acc: 0.6270
#
# Epoch 00084: val_acc did not improve from 0.68315
# Epoch 85/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3784 - acc: 0.8624 - val_loss: 1.3132 - val_acc: 0.6404
#
# Epoch 00085: val_acc did not improve from 0.68315
# Epoch 86/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3445 - acc: 0.8792 - val_loss: 1.1486 - val_acc: 0.6652
#
# Epoch 00086: val_acc did not improve from 0.68315
# Epoch 87/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3497 - acc: 0.8865 - val_loss: 1.2317 - val_acc: 0.6764
#
# Epoch 00087: val_acc did not improve from 0.68315
# Epoch 88/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3068 - acc: 0.9107 - val_loss: 1.3900 - val_acc: 0.6652
#
# Epoch 00088: val_acc did not improve from 0.68315
# Epoch 89/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2718 - acc: 0.9129 - val_loss: 1.3628 - val_acc: 0.6764
#
# Epoch 00089: val_acc did not improve from 0.68315
# Epoch 90/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2808 - acc: 0.9084 - val_loss: 1.2423 - val_acc: 0.6764
#
# Epoch 00090: val_acc did not improve from 0.68315
# Epoch 91/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2801 - acc: 0.9011 - val_loss: 1.3549 - val_acc: 0.6697
#
# Epoch 00091: val_acc did not improve from 0.68315
# Epoch 92/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3104 - acc: 0.9000 - val_loss: 1.3007 - val_acc: 0.6719
#
# Epoch 00092: val_acc did not improve from 0.68315
# Epoch 93/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3225 - acc: 0.8854 - val_loss: 1.4244 - val_acc: 0.6427
#
# Epoch 00093: val_acc did not improve from 0.68315
# Epoch 94/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3220 - acc: 0.8758 - val_loss: 1.4826 - val_acc: 0.6674
#
# Epoch 00094: val_acc did not improve from 0.68315
# Epoch 95/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2903 - acc: 0.8989 - val_loss: 1.4554 - val_acc: 0.6629
#
# Epoch 00095: val_acc did not improve from 0.68315
# Epoch 96/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3225 - acc: 0.8882 - val_loss: 1.3611 - val_acc: 0.6517
#
# Epoch 00096: val_acc did not improve from 0.68315
# Epoch 97/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2753 - acc: 0.9022 - val_loss: 1.4828 - val_acc: 0.6607
#
# Epoch 00097: val_acc did not improve from 0.68315
# Epoch 98/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2989 - acc: 0.8916 - val_loss: 1.3476 - val_acc: 0.6674
#
# Epoch 00098: val_acc did not improve from 0.68315
# Epoch 99/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2764 - acc: 0.8989 - val_loss: 1.5536 - val_acc: 0.6764
#
# Epoch 00099: val_acc did not improve from 0.68315
# Epoch 100/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2671 - acc: 0.9112 - val_loss: 1.5370 - val_acc: 0.6854
#
# Epoch 00100: val_acc improved from 0.68315 to 0.68539, saving model to model.h5
# Epoch 101/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2508 - acc: 0.9112 - val_loss: 1.4343 - val_acc: 0.6629
#
# Epoch 00101: val_acc did not improve from 0.68539
# Epoch 102/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2659 - acc: 0.8978 - val_loss: 1.5583 - val_acc: 0.6674
#
# Epoch 00102: val_acc did not improve from 0.68539
# Epoch 103/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3441 - acc: 0.8730 - val_loss: 1.7209 - val_acc: 0.6517
#
# Epoch 00103: val_acc did not improve from 0.68539
# Epoch 104/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3281 - acc: 0.8860 - val_loss: 1.4821 - val_acc: 0.6494
#
# Epoch 00104: val_acc did not improve from 0.68539
# Epoch 105/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3291 - acc: 0.8904 - val_loss: 1.5649 - val_acc: 0.6315
#
# Epoch 00105: val_acc did not improve from 0.68539
# Epoch 106/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3047 - acc: 0.8876 - val_loss: 1.5522 - val_acc: 0.6539
#
# Epoch 00106: val_acc did not improve from 0.68539
# Epoch 107/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2708 - acc: 0.8994 - val_loss: 1.3563 - val_acc: 0.6809
#
# Epoch 00107: val_acc did not improve from 0.68539
# Epoch 108/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2429 - acc: 0.9084 - val_loss: 1.4580 - val_acc: 0.6697
#
# Epoch 00108: val_acc did not improve from 0.68539
# Epoch 109/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2076 - acc: 0.9253 - val_loss: 1.5925 - val_acc: 0.6607
#
# Epoch 00109: val_acc did not improve from 0.68539
# Epoch 110/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2567 - acc: 0.9124 - val_loss: 1.6253 - val_acc: 0.6360
#
# Epoch 00110: val_acc did not improve from 0.68539
# Epoch 111/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3260 - acc: 0.8803 - val_loss: 1.5578 - val_acc: 0.6202
#
# Epoch 00111: val_acc did not improve from 0.68539
# Epoch 112/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3949 - acc: 0.8618 - val_loss: 1.6670 - val_acc: 0.6202
#
# Epoch 00112: val_acc did not improve from 0.68539
# Epoch 113/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3747 - acc: 0.8736 - val_loss: 1.3822 - val_acc: 0.6472
#
# Epoch 00113: val_acc did not improve from 0.68539
# Epoch 114/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3367 - acc: 0.8775 - val_loss: 1.5193 - val_acc: 0.6494
#
# Epoch 00114: val_acc did not improve from 0.68539
# Epoch 115/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2712 - acc: 0.9056 - val_loss: 1.4413 - val_acc: 0.6652
#
# Epoch 00115: val_acc did not improve from 0.68539
# Epoch 116/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2228 - acc: 0.9253 - val_loss: 1.4150 - val_acc: 0.6629
#
# Epoch 00116: val_acc did not improve from 0.68539
# Epoch 117/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2570 - acc: 0.9045 - val_loss: 1.7354 - val_acc: 0.6337
#
# Epoch 00117: val_acc did not improve from 0.68539
# Epoch 118/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2526 - acc: 0.9073 - val_loss: 1.6807 - val_acc: 0.6472
#
# Epoch 00118: val_acc did not improve from 0.68539
# Epoch 119/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2376 - acc: 0.9157 - val_loss: 1.7117 - val_acc: 0.6539
#
# Epoch 00119: val_acc did not improve from 0.68539
# Epoch 120/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2418 - acc: 0.9079 - val_loss: 1.4511 - val_acc: 0.6404
#
# Epoch 00120: val_acc did not improve from 0.68539
# Epoch 121/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2393 - acc: 0.9157 - val_loss: 1.6301 - val_acc: 0.6652
#
# Epoch 00121: val_acc did not improve from 0.68539
# Epoch 122/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2034 - acc: 0.9303 - val_loss: 1.4941 - val_acc: 0.6854
#
# Epoch 00122: val_acc improved from 0.68539 to 0.68539, saving model to model.h5
# Epoch 123/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2107 - acc: 0.9331 - val_loss: 1.5785 - val_acc: 0.6697
#
# Epoch 00123: val_acc did not improve from 0.68539
# Epoch 124/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2028 - acc: 0.9236 - val_loss: 1.6482 - val_acc: 0.6472
#
# Epoch 00124: val_acc did not improve from 0.68539
# Epoch 125/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2092 - acc: 0.9236 - val_loss: 1.6515 - val_acc: 0.6494
#
# Epoch 00125: val_acc did not improve from 0.68539
# Epoch 126/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2206 - acc: 0.9225 - val_loss: 1.7237 - val_acc: 0.6292
#
# Epoch 00126: val_acc did not improve from 0.68539
# Epoch 127/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2479 - acc: 0.9039 - val_loss: 1.5867 - val_acc: 0.6607
#
# Epoch 00127: val_acc did not improve from 0.68539
# Epoch 128/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2509 - acc: 0.9163 - val_loss: 1.7910 - val_acc: 0.6652
#
# Epoch 00128: val_acc did not improve from 0.68539
# Epoch 129/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3908 - acc: 0.8590 - val_loss: 2.4222 - val_acc: 0.5573
#
# Epoch 00129: val_acc did not improve from 0.68539
# Epoch 130/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3981 - acc: 0.8635 - val_loss: 1.9174 - val_acc: 0.6427
#
# Epoch 00130: val_acc did not improve from 0.68539
# Epoch 131/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3716 - acc: 0.8775 - val_loss: 1.5541 - val_acc: 0.6517
#
# Epoch 00131: val_acc did not improve from 0.68539
# Epoch 132/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3631 - acc: 0.8708 - val_loss: 1.3398 - val_acc: 0.6607
#
# Epoch 00132: val_acc did not improve from 0.68539
# Epoch 133/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.3443 - acc: 0.8831 - val_loss: 1.3212 - val_acc: 0.6652
#
# Epoch 00133: val_acc did not improve from 0.68539
# Epoch 134/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3138 - acc: 0.8972 - val_loss: 1.3474 - val_acc: 0.6247
#
# Epoch 00134: val_acc did not improve from 0.68539
# Epoch 135/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3034 - acc: 0.8888 - val_loss: 1.4957 - val_acc: 0.6449
#
# Epoch 00135: val_acc did not improve from 0.68539
# Epoch 136/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2650 - acc: 0.9079 - val_loss: 1.4436 - val_acc: 0.6292
#
# Epoch 00136: val_acc did not improve from 0.68539
# Epoch 137/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2501 - acc: 0.9208 - val_loss: 1.5323 - val_acc: 0.6607
#
# Epoch 00137: val_acc did not improve from 0.68539
# Epoch 138/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2230 - acc: 0.9258 - val_loss: 1.5434 - val_acc: 0.6764
#
# Epoch 00138: val_acc did not improve from 0.68539
# Epoch 139/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2149 - acc: 0.9219 - val_loss: 1.5914 - val_acc: 0.6876
#
# Epoch 00139: val_acc improved from 0.68539 to 0.68764, saving model to model.h5
# Epoch 140/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2027 - acc: 0.9281 - val_loss: 1.6713 - val_acc: 0.6697
#
# Epoch 00140: val_acc did not improve from 0.68764
# Epoch 141/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2118 - acc: 0.9208 - val_loss: 1.6265 - val_acc: 0.6472
#
# Epoch 00141: val_acc did not improve from 0.68764
# Epoch 142/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2020 - acc: 0.9281 - val_loss: 1.8000 - val_acc: 0.6742
#
# Epoch 00142: val_acc did not improve from 0.68764
# Epoch 143/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.1889 - acc: 0.9320 - val_loss: 1.6756 - val_acc: 0.6517
#
# Epoch 00143: val_acc did not improve from 0.68764
# Epoch 144/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.1822 - acc: 0.9337 - val_loss: 1.6586 - val_acc: 0.6899
#
# Epoch 00144: val_acc improved from 0.68764 to 0.68989, saving model to model.h5
# Epoch 145/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.1995 - acc: 0.9264 - val_loss: 1.6551 - val_acc: 0.6607
#
# Epoch 00145: val_acc did not improve from 0.68989
# Epoch 146/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2486 - acc: 0.9096 - val_loss: 1.9745 - val_acc: 0.6360
#
# Epoch 00146: val_acc did not improve from 0.68989
# Epoch 147/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.4069 - acc: 0.8461 - val_loss: 2.0820 - val_acc: 0.5708
#
# Epoch 00147: val_acc did not improve from 0.68989
# Epoch 148/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.5498 - acc: 0.8124 - val_loss: 2.3348 - val_acc: 0.5146
#
# Epoch 00148: val_acc did not improve from 0.68989
# Epoch 149/180
# 1780/1780 [==============================] - 7s 4ms/step - loss: 1.3085 - acc: 0.6000 - val_loss: 1.9596 - val_acc: 0.3865
#
# Epoch 00149: val_acc did not improve from 0.68989
# Epoch 150/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 1.0801 - acc: 0.6039 - val_loss: 1.6556 - val_acc: 0.4157
#
# Epoch 00150: val_acc did not improve from 0.68989
# Epoch 151/180
# 1780/1780 [==============================] - 7s 4ms/step - loss: 0.8393 - acc: 0.6927 - val_loss: 1.3664 - val_acc: 0.5506
#
# Epoch 00151: val_acc did not improve from 0.68989
# Epoch 152/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.7768 - acc: 0.7084 - val_loss: 1.4519 - val_acc: 0.5101
#
# Epoch 00152: val_acc did not improve from 0.68989
# Epoch 153/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6504 - acc: 0.7618 - val_loss: 1.4994 - val_acc: 0.4966
#
# Epoch 00153: val_acc did not improve from 0.68989
# Epoch 154/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.7276 - acc: 0.7180 - val_loss: 1.4168 - val_acc: 0.5034
#
# Epoch 00154: val_acc did not improve from 0.68989
# Epoch 155/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.6047 - acc: 0.7820 - val_loss: 1.3522 - val_acc: 0.5730
#
# Epoch 00155: val_acc did not improve from 0.68989
# Epoch 156/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.5007 - acc: 0.8140 - val_loss: 1.4194 - val_acc: 0.5910
#
# Epoch 00156: val_acc did not improve from 0.68989
# Epoch 157/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.5545 - acc: 0.7989 - val_loss: 1.3817 - val_acc: 0.6045
#
# Epoch 00157: val_acc did not improve from 0.68989
# Epoch 158/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.4741 - acc: 0.8275 - val_loss: 1.3194 - val_acc: 0.6337
#
# Epoch 00158: val_acc did not improve from 0.68989
# Epoch 159/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3788 - acc: 0.8742 - val_loss: 1.4090 - val_acc: 0.6247
#
# Epoch 00159: val_acc did not improve from 0.68989
# Epoch 160/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3775 - acc: 0.8742 - val_loss: 1.3216 - val_acc: 0.6292
#
# Epoch 00160: val_acc did not improve from 0.68989
# Epoch 161/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3763 - acc: 0.8624 - val_loss: 1.4298 - val_acc: 0.6674
#
# Epoch 00161: val_acc did not improve from 0.68989
# Epoch 162/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3323 - acc: 0.8798 - val_loss: 1.3247 - val_acc: 0.6292
#
# Epoch 00162: val_acc did not improve from 0.68989
# Epoch 163/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3177 - acc: 0.8893 - val_loss: 1.3184 - val_acc: 0.6472
#
# Epoch 00163: val_acc did not improve from 0.68989
# Epoch 164/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2897 - acc: 0.8983 - val_loss: 1.4036 - val_acc: 0.6652
#
# Epoch 00164: val_acc did not improve from 0.68989
# Epoch 165/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2718 - acc: 0.9039 - val_loss: 1.5071 - val_acc: 0.6742
#
# Epoch 00165: val_acc did not improve from 0.68989
# Epoch 166/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3087 - acc: 0.8888 - val_loss: 1.4028 - val_acc: 0.6449
#
# Epoch 00166: val_acc did not improve from 0.68989
# Epoch 167/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2438 - acc: 0.9191 - val_loss: 1.3704 - val_acc: 0.6629
#
# Epoch 00167: val_acc did not improve from 0.68989
# Epoch 168/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2781 - acc: 0.8961 - val_loss: 1.4263 - val_acc: 0.6360
#
# Epoch 00168: val_acc did not improve from 0.68989
# Epoch 169/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.3328 - acc: 0.8815 - val_loss: 1.5556 - val_acc: 0.6090
#
# Epoch 00169: val_acc did not improve from 0.68989
# Epoch 170/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2779 - acc: 0.9062 - val_loss: 1.5339 - val_acc: 0.6315
#
# Epoch 00170: val_acc did not improve from 0.68989
# Epoch 171/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2486 - acc: 0.9140 - val_loss: 1.4716 - val_acc: 0.6382
#
# Epoch 00171: val_acc did not improve from 0.68989
# Epoch 172/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2288 - acc: 0.9236 - val_loss: 1.7229 - val_acc: 0.6427
#
# Epoch 00172: val_acc did not improve from 0.68989
# Epoch 173/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2328 - acc: 0.9202 - val_loss: 1.7223 - val_acc: 0.6494
#
# Epoch 00173: val_acc did not improve from 0.68989
# Epoch 174/180
# 1780/1780 [==============================] - 6s 3ms/step - loss: 0.2345 - acc: 0.9208 - val_loss: 1.4890 - val_acc: 0.6360
#
# Epoch 00174: val_acc did not improve from 0.68989
# Epoch 175/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2246 - acc: 0.9180 - val_loss: 1.7027 - val_acc: 0.6584
#
# Epoch 00175: val_acc did not improve from 0.68989
# Epoch 176/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2287 - acc: 0.9197 - val_loss: 1.5558 - val_acc: 0.6584
#
# Epoch 00176: val_acc did not improve from 0.68989
# Epoch 177/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.1982 - acc: 0.9292 - val_loss: 1.5044 - val_acc: 0.6607
#
# Epoch 00177: val_acc did not improve from 0.68989
# Epoch 178/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2013 - acc: 0.9320 - val_loss: 1.7505 - val_acc: 0.6562
#
# Epoch 00178: val_acc did not improve from 0.68989
# Epoch 179/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.2109 - acc: 0.9219 - val_loss: 1.6046 - val_acc: 0.6629
#
# Epoch 00179: val_acc did not improve from 0.68989
# Epoch 180/180
# 1780/1780 [==============================] - 6s 4ms/step - loss: 0.1790 - acc: 0.9343 - val_loss: 1.6564 - val_acc: 0.6584
#
# Epoch 00180: val_acc did not improve from 0.68989
# Duration: 0:18:41.389553

# %%
def plot_history(hist):
    #print(hist.history.keys())

    # 精度の履歴をプロット
    plt.plot(hist.history['acc'])
    plt.plot(hist.history['val_acc'])
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(['acc', 'val_acc'], loc='upper left')
    plt.show()

    # 損失の履歴をプロット
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['loss', 'val_loss'], loc='upper left')
    plt.show()

# 学習履歴をプロット
plot_history(hist)

# %%
# モデルの設定

model = load_model("model.h5")
# Out:
# W0725 06:11:51.639023 140698915252096 nn_ops.py:4224] Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %%
#ytest = np.array(y_test)
ytest = np.argmax(y_test, axis=1)
pd = model.predict(X_test)
prediction = pd.argmax(1)

# %%
from sklearn.metrics import classification_report, confusion_matrix

#ytest = np.array(y_test)
ytest = np.argmax(y_test, axis=1)
pd = model.predict(X_test)
prediction = pd.argmax(1)


# confusion matrix and classification report(precision, recall, F1-score)
print(classification_report(ytest, prediction))
print(confusion_matrix(ytest, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81       102
#            1       0.74      0.62      0.68        77
#            2       0.66      0.63      0.64       102
#            3       0.73      0.70      0.71        80
#            4       0.56      0.61      0.58        84
#
#     accuracy                           0.69       445
#    macro avg       0.69      0.68      0.69       445
# weighted avg       0.69      0.69      0.69       445
#
# [[88  8  2  2  2]
#  [ 8 48  7  4 10]
#  [ 5  7 64  7 19]
#  [ 5  0 10 56  9]
#  [ 9  2 14  8 51]]

# %%
from sklearn.metrics import accuracy_score


accuracy = accuracy_score(ytest, prediction)
accuracy
# Out:
# 0.6898876404494382

# %% [markdown]
# ## 4. 推論

# %%
# 推論のスクリプト

def predictions(text):
  clean = re.sub(r'[^ a-z A-Z 0-9]', " ", text)
  test_word = word_tokenize(clean)
  test_word = [w.lower() for w in test_word]
  test_ls = word_tokenizer.texts_to_sequences(test_word)
  print(test_word)
  #Check for unknown words
  if [] in test_ls:
    test_ls = list(filter(None, test_ls))
    
  test_ls = np.array(test_ls).reshape(1, len(test_ls))
 
  x = padding_doc(test_ls, max_length)
  
  pred = model.predict_proba(x)
  
  return pred


def get_final_output(pred, classes):
  predictions = pred[0]
 
  classes = np.array(classes)
  ids = np.argsort(-predictions)
  classes = classes[ids]
  predictions = -np.sort(-predictions)
 
  for i in range(pred.shape[1]):
    print("%s has confidence = %s" % (classes[i], (predictions[i])))

# %%
# テスト

text = "European Championships: GB women reach wheelchair basketball final for first time"
pred = predictions(text)
get_final_output(pred, unique_category)
# Out:
# ['european', 'championships', 'gb', 'women', 'reach', 'wheelchair', 'basketball', 'final', 'for', 'first', 'time']
# sport has confidence = 0.9753758
# politics has confidence = 0.024623629
# entertainment has confidence = 6.031811e-07
# business has confidence = 4.562549e-08
# tech has confidence = 3.9513032e-10
